# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline

# %%
df = pd.read_csv(r"C:\Users\hp\Desktop\GlobalLandTemperaturesByCity1111.csv",delimiter=',')
df
# Out:
#                  dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0        1743-11-01               6.068                          1.737
# 1        1743-12-01                 NaN                            NaN
# 2        1744-01-01                 NaN                            NaN
# 3        1744-02-01                 NaN                            NaN
# 4        1744-03-01                 NaN                            NaN
# ...             ...                 ...                            ...
# 1048570  1784-04-01               9.541                          7.904
# 1048571  1784-05-01              17.364                          2.295
# 1048572  1784-06-01              19.406                          2.543
# 1048573  1784-07-01              21.318                          4.901
# 1048574  1784-08-01              19.559                          6.988
#
#              City  Country Latitude Longitude
# 0           Århus  Denmark   57.05N    10.33E
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count    Dtype
# ---  ------                         --------------    -----
#  0   dt                             1048575 non-null  object
#  1   AverageTemperature             1001028 non-null  float64
#  2   AverageTemperatureUncertainty  1001028 non-null  float64
#  3   City                           1048575 non-null  object
#  4   Country                        1048575 non-null  object
#  5   Latitude                       1048575 non-null  object
#  6   Longitude                      1048575 non-null  object
# dtypes: float64(2), object(5)
# memory usage: 56.0+ MB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 0  1743-11-01               6.068                          1.737  Århus
# 1  1743-12-01                 NaN                            NaN  Århus
# 2  1744-01-01                 NaN                            NaN  Århus
# 3  1744-02-01                 NaN                            NaN  Århus
# 4  1744-03-01                 NaN                            NaN  Århus
#
#    Country Latitude Longitude
# 0  Denmark   57.05N    10.33E
# 1  Denmark   57.05N    10.33E
# 2  Denmark   57.05N    10.33E
# 3  Denmark   57.05N    10.33E
# 4  Denmark   57.05N    10.33E

# %%
df.tail()
# Out:
#                  dt  AverageTemperature  AverageTemperatureUncertainty  \
# 1048570  1784-04-01               9.541                          7.904
# 1048571  1784-05-01              17.364                          2.295
# 1048572  1784-06-01              19.406                          2.543
# 1048573  1784-07-01              21.318                          4.901
# 1048574  1784-08-01              19.559                          6.988
#
#              City Country Latitude Longitude
# 1048570  Bordeaux  France   44.20N     0.00W
# 1048571  Bordeaux  France   44.20N     0.00W
# 1048572  Bordeaux  France   44.20N     0.00W
# 1048573  Bordeaux  France   44.20N     0.00W
# 1048574  Bordeaux  France   44.20N     0.00W

# %%
df.sample(100)
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 456052  01-06-1991              18.986                          0.227
# 402799  01-12-1966               6.938                          0.180
# 369541  01-08-1921              22.968                          0.971
# 486675  1881-12-01               1.661                          0.835
# 615143  1893-10-01              25.382                          0.666
# ...            ...                 ...                            ...
# 69020   01-12-1981             -14.971                          0.257
# 89898   1756-08-01              20.877                          5.740
# 545048  1881-10-01              24.707                          1.262
# 273166  01-04-1923              26.233                          0.554
# 556700  1863-09-01              11.052                          1.704
#
#                   City        Country Latitude Longitude
# 456052        Asunción       Paraguay   24.92S    58.52W
# ...

# %%
df['Country'].unique()
# Out:
# array(['Denmark', 'Turkey', 'Kazakhstan', 'China', 'Spain', 'Germany',
#        'Nigeria', 'Iran', 'Russia', 'Canada', "Côte D'Ivoire",
#        'United Kingdom', 'Saudi Arabia', 'Japan', 'United States',
#        'India', 'Benin', 'United Arab Emirates', 'Mexico', 'Venezuela',
#        'Ghana', 'Ethiopia', 'Australia', 'Yemen', 'Indonesia', 'Morocco',
#        'Pakistan', 'France', 'Libya', 'Burma', 'Brazil', 'South Africa',
#        'Syria', 'Egypt', 'Algeria', 'Netherlands', 'Malaysia', 'Portugal',
#        'Ecuador', 'Italy', 'Uzbekistan', 'Philippines', 'Madagascar',
#        'Chile', 'Belgium', 'El Salvador', 'Romania', 'Peru', 'Colombia',
#        'Tanzania', 'Tunisia', 'Turkmenistan', 'Israel', 'Eritrea',
#        'Paraguay', 'Greece', 'New Zealand', 'Vietnam', 'Cameroon', 'Iraq',
#        'Afghanistan', 'Argentina', 'Azerbaijan', 'Moldova', 'Mali',
#        'Congo (Democratic Republic Of The)', 'Thailand',
# ...

# %%
df['Country'].value_counts()
# Out:
# India            223750
# United States     63721
# Brazil            60852
# China             57703
# Russia            45866
#                   ...
# Angola             1878
# Saudi Arabia       1833
# Somalia            1797
# Eritrea            1797
# Yemen              1653
# Name: Country, Length: 85, dtype: int64

# %%
df.describe()
# Out:
#        AverageTemperature  AverageTemperatureUncertainty
# count        1.001028e+06                   1.001028e+06
# mean         1.792899e+01                   1.033831e+00
# std          1.035884e+01                   1.103003e+00
# min         -3.187400e+01                   3.600000e-02
# 25%          1.201700e+01                   3.480000e-01
# 50%          2.048600e+01                   6.070000e-01
# 75%          2.592600e+01                   1.380000e+00
# max          3.915600e+01                   1.503000e+01

# %%
df.select_dtypes('O')
# Out:
#                  dt      City  Country Latitude Longitude
# 0        1743-11-01     Århus  Denmark   57.05N    10.33E
# 1        1743-12-01     Århus  Denmark   57.05N    10.33E
# 2        1744-01-01     Århus  Denmark   57.05N    10.33E
# 3        1744-02-01     Århus  Denmark   57.05N    10.33E
# 4        1744-03-01     Århus  Denmark   57.05N    10.33E
# ...             ...       ...      ...      ...       ...
# 1048570  1784-04-01  Bordeaux   France   44.20N     0.00W
# 1048571  1784-05-01  Bordeaux   France   44.20N     0.00W
# 1048572  1784-06-01  Bordeaux   France   44.20N     0.00W
# 1048573  1784-07-01  Bordeaux   France   44.20N     0.00W
# 1048574  1784-08-01  Bordeaux   France   44.20N     0.00W
#
# [1048575 rows x 5 columns]

# %%
df.drop(['City','Latitude','Longitude'],axis=1,inplace=True)

# %%
df.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty  Country
# 0  1743-11-01               6.068                          1.737  Denmark
# 1  1743-12-01                 NaN                            NaN  Denmark
# 2  1744-01-01                 NaN                            NaN  Denmark
# 3  1744-02-01                 NaN                            NaN  Denmark
# 4  1744-03-01                 NaN                            NaN  Denmark

# %%
df_India = df.drop('AverageTemperatureUncertainty', axis=1)

# %%
df_India = df_India[df_India.Country == "India"]

# %%
df_India
# Out:
#                  dt  AverageTemperature Country
# 49880    1816-03-01              19.934   India
# 49881    1816-04-01              26.641   India
# 49882    1816-05-01              32.535   India
# 49883    1816-06-01              33.254   India
# 49884    1816-07-01              31.105   India
# ...             ...                 ...     ...
# 1042576  01-05-2013              29.718   India
# 1042577  01-06-2013              27.686   India
# 1042578  01-07-2013              26.519   India
# 1042579  01-08-2013              26.953   India
# 1042580  01-09-2013              26.953   India
#
# [223750 rows x 3 columns]

# %%
df_India = df_India.drop('Country',axis=1)

# %%
df_India
# Out:
#                  dt  AverageTemperature
# 49880    1816-03-01              19.934
# 49881    1816-04-01              26.641
# 49882    1816-05-01              32.535
# 49883    1816-06-01              33.254
# 49884    1816-07-01              31.105
# ...             ...                 ...
# 1042576  01-05-2013              29.718
# 1042577  01-06-2013              27.686
# 1042578  01-07-2013              26.519
# 1042579  01-08-2013              26.953
# 1042580  01-09-2013              26.953
#
# [223750 rows x 2 columns]

# %%
df_India.index = pd.to_datetime(df_India.dt)

# %%
df_India
# Out:
#                     dt  AverageTemperature
# dt
# 1816-03-01  1816-03-01              19.934
# 1816-04-01  1816-04-01              26.641
# 1816-05-01  1816-05-01              32.535
# 1816-06-01  1816-06-01              33.254
# 1816-07-01  1816-07-01              31.105
# ...                ...                 ...
# 2013-01-05  01-05-2013              29.718
# 2013-01-06  01-06-2013              27.686
# 2013-01-07  01-07-2013              26.519
# 2013-01-08  01-08-2013              26.953
# 2013-01-09  01-09-2013              26.953
#
# [223750 rows x 2 columns]

# %%
df_India = df_India.drop('dt', axis=1)

# %%
df_India
# Out:
#             AverageTemperature
# dt
# 1816-03-01              19.934
# 1816-04-01              26.641
# 1816-05-01              32.535
# 1816-06-01              33.254
# 1816-07-01              31.105
# ...                        ...
# 2013-01-05              29.718
# 2013-01-06              27.686
# 2013-01-07              26.519
# 2013-01-08              26.953
# 2013-01-09              26.953
#
# [223750 rows x 1 columns]

# %%
df_India = df_India.loc['1970-01-01':]

# %%
df_India.head()
# Out:
#             AverageTemperature
# dt
# 1970-01-01              13.027
# 1970-01-02              15.301
# 1970-01-03              20.847
# 1970-01-04              29.236
# 1970-01-05              33.912

# %%
df_India[df_India.isnull()]
# Out:
#             AverageTemperature
# dt
# 1970-01-01                 NaN
# 1970-01-02                 NaN
# 1970-01-03                 NaN
# 1970-01-04                 NaN
# 1970-01-05                 NaN
# ...                        ...
# 2013-01-05                 NaN
# 2013-01-06                 NaN
# 2013-01-07                 NaN
# 2013-01-08                 NaN
# 2013-01-09                 NaN
#
# [45150 rows x 1 columns]

# %%
len(df_India[df_India.isnull()])
# Out:
# 45150

# %%
df_India = df_India.sort_index()

# %%
df_India.index
# Out:
# DatetimeIndex(['1970-01-01', '1970-01-01', '1970-01-01', '1970-01-01',
#                '1970-01-01', '1970-01-01', '1970-01-01', '1970-01-01',
#                '1970-01-01', '1970-01-01',
#                ...
#                '2013-01-09', '2013-01-09', '2013-01-09', '2013-01-09',
#                '2013-01-09', '2013-01-09', '2013-01-09', '2013-01-09',
#                '2013-01-09', '2013-01-09'],
#               dtype='datetime64[ns]', name='dt', length=45150, freq=None)

# %%
df_India.AverageTemperature.fillna(method='pad', inplace=True)

# %%
df_India[df_India.AverageTemperature.isnull()]
# Out:
# Empty DataFrame
# Columns: [AverageTemperature]
# Index: []

# %%
df_India.describe()
# Out:
#        AverageTemperature
# count        45150.000000
# mean            26.279607
# std              4.791977
# min             11.006000
# 25%             23.421250
# 50%             27.245000
# 75%             29.577000
# max             37.522000

# %%
df_India['Ticks'] = range(0,len(df_India.index.values))

# %%
df_India.head(10)
# Out:
#             AverageTemperature  Ticks
# dt
# 1970-01-01              13.027      0
# 1970-01-01              16.019      1
# 1970-01-01              12.599      2
# 1970-01-01              16.777      3
# 1970-01-01              17.543      4
# 1970-01-01              16.583      5
# 1970-01-01              26.671      6
# 1970-01-01              19.162      7
# 1970-01-01              20.151      8
# 1970-01-01              20.111      9

# %%
df_India.tail(10)
# Out:
#             AverageTemperature  Ticks
# dt
# 2013-01-09              29.667  45140
# 2013-01-09              30.040  45141
# 2013-01-09              29.654  45142
# 2013-01-09              29.608  45143
# 2013-01-09              25.328  45144
# 2013-01-09              27.524  45145
# 2013-01-09              29.791  45146
# 2013-01-09              24.458  45147
# 2013-01-09              29.539  45148
# 2013-01-09              26.953  45149

# %%
fig = plt.figure(1)
ax1 = fig.add_subplot(111)
ax1.set_xlabel('Ticks')
ax1.set_ylabel('Avg. Temp.')
ax1.set_title('Original Plot')
ax1.plot('Ticks', 'AverageTemperature', data = df_India);

# %%
df_India
# Out:
#             AverageTemperature  Ticks
# dt
# 1970-01-01              13.027      0
# 1970-01-01              16.019      1
# 1970-01-01              12.599      2
# 1970-01-01              16.777      3
# 1970-01-01              17.543      4
# ...                        ...    ...
# 2013-01-09              27.524  45145
# 2013-01-09              29.791  45146
# 2013-01-09              24.458  45147
# 2013-01-09              29.539  45148
# 2013-01-09              26.953  45149
#
# [45150 rows x 2 columns]

# %%
from statsmodels.tsa.stattools import adfuller

def adf_test(dataset):
    dftest = adfuller(dataset, autolag = 'AIC')
    print("1. ADF : ",dftest[0])
    print("2. P-Value : ", dftest[1])
    print("3. Num Of Lags : ", dftest[2])
    print("4. Num Of Observations Used For ADF Regression and Critical Values Calculation :", dftest[3])
    print("5. Critical Values :")
    for key, val in dftest[4].items():
        print("\t",key, ": ", val)

# %%
adf_test(df_India['AverageTemperature'])
# Out:
# 1. ADF :  -7.733812279047169
# 2. P-Value :  1.1072654732407215e-11
# 3. Num Of Lags :  27
# 4. Num Of Observations Used For ADF Regression and Critical Values Calculation : 45122
# 5. Critical Values :
# 	 1% :  -3.430494933115834
# 	 5% :  -2.8616040573080572
# 	 10% :  -2.5668040956130813

# %%
pip install pmdarima
# Out:
# ...
#
# ...

# %%
from pmdarima import auto_arima
import warnings
warnings.filterwarnings("ignore")

# %%
stepwise_fit = auto_arima(df_India['AverageTemperature'], 
                          suppress_warnings=True)           

stepwise_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                45150
# Model:               SARIMAX(0, 1, 1)   Log Likelihood             -103970.793
# Date:                Thu, 11 Apr 2024   AIC                         207945.586
# Time:                        21:09:50   BIC                         207963.021
# Sample:                             0   HQIC                        207951.073
#                               - 45150
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.8832      0.002   -464.950      0.000      -0.887      -0.879
# sigma2         5.8576      0.034    170.798      0.000       5.790       5.925
# ...
# Ljung-Box (L1) (Q):                   1.34   Jarque-Bera (JB):               696.13
# ...

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
import statsmodels.api as sm
from statsmodels.tsa.arima_model import ARIMA

# %%
from statsmodels.graphics.tsaplots import plot_pacf,plot_acf

# %%
plot_acf(df_India.AverageTemperature, lags=50)
plot_pacf(df_India.AverageTemperature, lags=50)
plt.xlabel('lags')
plt.show()

# %%
from statsmodels.tsa.arima_model import ARMA

# %%
import itertools
p = q = range(0, 4)
pq = itertools.product(p, q)
for param in pq:
    try:
        mod = ARMA(df_India.AverageTemperature,order=param)
        results = mod.fit()
        print('ARMA{} - AIC:{}'.format(param, results.aic))
    except:
        continue

# %%
model = sm.tsa.arima.ARIMA(df_India.AverageTemperature, order=(1,0,5))  
results_MA = model.fit()  
plt.plot(df_India.AverageTemperature)
plt.plot(results_MA.fittedvalues, color='red')
plt.title('Fitting data _ MSE: %.2f'% (((results_MA.fittedvalues-df_India.AverageTemperature)**2).mean()))
plt.show()

# %%
pred=results_MA.predict(start=len(df_India),end=len(df)+30,typ='levels').rename('ARIMA Predictions')

# %%
pred
# Out:
# 45150      28.047047
# 45151      28.048807
# 45152      28.023515
# 45153      28.027617
# 45154      28.017609
#              ...
# 1048601    26.272535
# 1048602    26.272535
# 1048603    26.272535
# 1048604    26.272535
# 1048605    26.272535
# Name: ARIMA Predictions, Length: 1003456, dtype: float64
